# %% [markdown]
# <a href="https://colab.research.google.com/github/MooCow381/ALPprojects/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(
    "why did the chicken cross the road"
     "                           "
      "To get to the other side"
)
# Out:
# why did the chicken cross the road                           To get to the other side

# %%
favColor = "blue"
animal = "dog"
if(favColor == "blue"):
  print(favColor + animal)
else:
  print(favColor + "cat")
# Out:
# bluedog

# %%
color1 = "red"
color2 = "blue"
print("My favorite food is " + color1 + " and " + color2 + ".")
# Out:
# My favorite food is red and blue.

# %% [markdown]
# prograaming input

# %%
print("what is your name?")
name = input()
print("hello " + name)
# Out:
# what is your name?
# f
# hello f

# %%
print ("1+1= ")
answer = input()
if answer == "2":
  print("correct")
else:
  print("wrong")
  print("second chance")
  secondAnswer = input()
  if secondAnswer == "2":
    print("correct")
  else:
    print("wrong again")

# %% [markdown]
# #Chat Bot

# %%
print("What is your name?")
name = input()
print("Hello " + name)
print ("do you like spaghetti?")
likesSpaghetti = input()
if likesSpaghetti == "yes":
  likesSpaghetti = "yes"
  print("What is your favorite type of spaghetti?")
  favoriteSpaghetti = input()
  print("well I think that " + favoriteSpaghetti + " tastes like dog poop")
elif likesSpaghetti == "I HAVE A BOMB!":
  print("AAAAAAAAAAAAAAAAAAAAAAAA")
else:
  likesSpaghetti = "no"
  print("do you like water then?")
  likesWater = input()
  if likesWater == "yes":
    print("what is your favorite type of water")
    favoriteWater = input()
    if favoriteWater == "normal water" or "just water" or "regular water" or "water":
      print("I like that too")
    else:
      print("I don't think that's a real water")
  else:
    print("are you the wicked witch of the west or somthing?")
    isWickedWitch = input()
    if isWickedWitch == "yes":
          print("please don't sick your monkeys on me then")
    else:
      print("then that's good")
# Out:
# What is your name?
# jayvyn
# Hello jayvyn
# do you like spaghetti?
# yes
# What is your favorite type of spaghetti?
# green
# well I think that green tastes like dog poop

# %%
score = 5
print(score)
score += 1
print(score)
# Out:
# 5
# 6

# %%
num1 = int(input("enter a number"))
print(3*num1)
num2 = (input())
print(5*num2)
# Out:
# enter a number3
# 9
# 5
# 55555

# %%
thing = input()
print(9999*thing)
# Out:
# fortnine balls
# ...

# %%
width = int(input("Width "))
length = int(input("length "))
print("area " + str(width * length))
# Out:
# Width 5
# length 6
# area 30

# %%
run = "yes"
print("Ask yourself a question")
question = input()
print(question)
while (run == "yes"):
  question = input()
  print("why is it " + question + "?")

# %% [markdown]
# tip calculator

# %%
print("what is cost?")
cost = int(input())
print("$" + str(cost * 0.2))
# Out:
# what is cost?
# 4
# $0.8

# %% [markdown]
# surface area and volume calculator

# %%
width = int(input("width "))
length = int(input("length "))
height = int(input("height "))
print("voume " + str(width*length*height))
print("surface area " + str(2*((width*length)+ (width*height)+(height*length))))
# Out:
# width 5
# length 4
# height 3
# voume 60
# surface area 94

# %%
num1 = input("number ")
num2 = input("another number ")
if num1 > num2:
  print("the first number is bigger")
else:
  print("the second number is bigger")
# Out:
# number 2
# another number 4
# the second number is bigger

# %%
password = str(1337)
print("password")
anwser = input()
if anwser == password:
  print("correct")
else:
  print("wrong")
# Out:
# password
# 1337
# correct

# %%
num1 = int(input("number "))
num2 = int(input("another number "))
if num1 > num2:
  print(num1)
elif (num1 == num2):
  print("same")
else:
  print(num2)
# Out:
# number 3
# another number 3
# same

# %%
name = input("name? ")
number = input("number")
if number == "1":
  print(name + ", you look like a dog")
elif number == "2":
  print(name + ", you look like a lizard")
elif number == "3":
  print(name + ", you look like a horse")
elif number == "4":
  print(name + ", you look like a rat")
elif number == "5":
  print(name + ", you look like a zebra")
else:
  print("that's not a number you idiot")
# Out:
# name? s
# number2
# s, you look like a lizard

# %%
counter = 1
while counter <= 999999999999999999999999999999999:
  print("fortnite balls")
  counter += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# fortnite balls
# ...

# %%
print("fortnite balls")
# Out:
# fortnite balls

# %%
secretnumber = 7
wow = int(input("Guess a Number: "))
while wow != secretnumber:
    wow = int(input("Guess again: "))
print("Good job!!!!")

# %%
multiplier = int(1)
while multiplier < 13:
  print(7 * multiplier)
  multiplier += 1
# Out:
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84

# %%
number = int(input("number "))
currentnumber = number
numbercounter = 1
while numbercounter < number:
  currentnumber = currentnumber * numbercounter
  print(currentnumber)
  numbercounter +=1
# Out:
# number 6
# 6
# 12
# 36
# 144
# 720
