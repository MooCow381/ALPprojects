# %% [markdown]
# <a href="https://colab.research.google.com/github/MooCow381/ALPprojects/blob/main/Actual_friday_assingment_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

maxHp = 100
enemyMaxHp = 100
currentHp = 100
enemyHp = 100
wonBattle = "no"
dead = "no"

def damagePlayer(currentHp, maxHp):
  enemyDamage = random.randrange(1, 21)
  currentHp -= enemyDamage
  global c
  c= currentHp
  print(str("The enemy did ") + str(enemyDamage) + str(" damage."))
  print(str("You are at ") + str(c) + str("/") + str(maxHp) + str(" Hp"))

def damageEnemy(enemyHp, enemyMaxHp):
  playerDamage = random.randrange(1, 21)
  enemyHp -= playerDamage
  global e
  e = enemyHp
  print(str("You did ") + str(playerDamage) + str(" damage."))
  print(str("The enemy is at ") + str(e) + str("/") + str(enemyMaxHp) + str(" Hp"))

while wonBattle == "no" and dead == "no":
  playerAttack = input("Choose: 1 for Rock, 2 for Paper, 3 for Scissors ")
  enemyAttack = int(random.randrange(1,4))

  if playerAttack == "1":
    print("You played rock")

    if enemyAttack == 2:
      print("The enemy played paper")
      damageEnemy(enemyHp, enemyMaxHp)
      enemyHp = e

    if enemyAttack == 3:
      print("The enemy played scissors")
      damagePlayer(currentHp, maxHp)
      currentHp = c

    if enemyAttack == 1:
      print("The enemy played rock")
      print("You tied, nothing happend")

  elif playerAttack == "2":
    print("You played paper")

    if enemyAttack == 3:
      print("The enemy played scissors")
      damagePlayer(currentHp, maxHp)
      currentHp = c

    if enemyAttack == 1:
      print("The enemy played rock")
      damageEnemy(enemyHp, enemyMaxHp)
      enemyHp = e

    if enemyAttack == 2:
      print("The enemy played paper")
      print("You tied, nothing happend")

  elif playerAttack == "3":
    print("You played scissors")

    if enemyAttack == 1:
      print("The enemy played rock")
      damagePlayer(currentHp, maxHp)
      currentHp = c

    if enemyAttack == 2:
      print("The enemy played paper")
      damageEnemy(enemyHp, enemyMaxHp)
      enemyHp = e

    if enemyAttack == 3:
      print("The enemy played scissors")
      print("You tied, nothing happend")

  else:
    print("Invaild command")

  if enemyHp <= 0:
    wonBattle = "yes"
    print("you won")
  if currentHp <= 0:
    dead = "yes"
    print("Game over")
# Out:
# Choose: 1 for Rock, 2 for Paper, 3 for Scissors 1
# You played rock
# The enemy played rock
# You tied, nothing happend
# Choose: 1 for Rock, 2 for Paper, 3 for Scissors 1
# You played rock
# The enemy played paper
# You did 17 damage.
# The enemy is at 83/100 Hp
# Choose: 1 for Rock, 2 for Paper, 3 for Scissors 3
# You played scissors
# The enemy played rock
# The enemy did 12 damage.
# You are at 88/100 Hp
# Choose: 1 for Rock, 2 for Paper, 3 for Scissors 2
# You played paper
# The enemy played rock
# You did 16 damage.
# The enemy is at 67/100 Hp
# Choose: 1 for Rock, 2 for Paper, 3 for Scissors 2
# You played paper
# The enemy played scissors
# The enemy did 11 damage.
# You are at 77/100 Hp
# Choose: 1 for Rock, 2 for Paper, 3 for Scissors 1
# You played rock
# The enemy played rock
# You tied, nothing happend
# Choose: 1 for Rock, 2 for Paper, 3 for Scissors 2
# You played paper
# The enemy played scissors
# The enemy did 3 damage.
# You are at 74/100 Hp
# ...
